# %%
from keras.layers import Dense
from keras.models import Sequential
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
dfDiabetes = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')
dfDiabetes.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
X_diabetes = dfDiabetes.drop('Outcome', axis=1).values
y_diabetes = dfDiabetes['Outcome'].values

# %%
X_diabetes.shape
# Out:
# (768, 8)

# %%
scaladito = MinMaxScaler()
X_diabetes = scaladito.fit_transform(X_diabetes)

X_diabetes[:2]
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, 0.35353535, 0.        ,
#         0.50074516, 0.23441503, 0.48333333],
#        [0.05882353, 0.42713568, 0.54098361, 0.29292929, 0.        ,
#         0.39642325, 0.11656704, 0.16666667]])

# %%
nn = Sequential()
nn.add(Dense(400, input_dim=8, activation='relu'))
nn.add(Dense(150, activation='relu'))

nn.add(Dense(1, activation='sigmoid'))

nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
nn.fit(X_diabetes, y_diabetes, epochs=150, batch_size=10, validation_split=0.3, verbose=2)
# Out:
# Epoch 1/150
# 54/54 - 2s - loss: 0.6391 - accuracy: 0.6518 - val_loss: 0.5900 - val_accuracy: 0.7229 - 2s/epoch - 43ms/step
# Epoch 2/150
# 54/54 - 0s - loss: 0.5863 - accuracy: 0.6946 - val_loss: 0.5400 - val_accuracy: 0.7489 - 249ms/epoch - 5ms/step
# Epoch 3/150
# 54/54 - 0s - loss: 0.5550 - accuracy: 0.7151 - val_loss: 0.5061 - val_accuracy: 0.7403 - 472ms/epoch - 9ms/step
# Epoch 4/150
# 54/54 - 0s - loss: 0.5234 - accuracy: 0.7263 - val_loss: 0.5016 - val_accuracy: 0.7749 - 439ms/epoch - 8ms/step
# Epoch 5/150
# 54/54 - 0s - loss: 0.5078 - accuracy: 0.7579 - val_loss: 0.4598 - val_accuracy: 0.7792 - 458ms/epoch - 8ms/step
# Epoch 6/150
# 54/54 - 0s - loss: 0.5043 - accuracy: 0.7467 - val_loss: 0.4450 - val_accuracy: 0.8312 - 437ms/epoch - 8ms/step
# Epoch 7/150
# 54/54 - 0s - loss: 0.5006 - accuracy: 0.7579 - val_loss: 0.4438 - val_accuracy: 0.8095 - 304ms/epoch - 6ms/step
# Epoch 8/150
# ...

# %%
scores = nn.evaluate(X_diabetes, y_diabetes)
scores
# Out:
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8438
# [0.3904127776622772, 0.84375]
